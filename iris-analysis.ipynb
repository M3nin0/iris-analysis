# %%
import numpy as np
from Process import Process

'''
1° Coluna: Valores do comprimento da sépalas;
2° Coluna: Valores da largula da sépala;
3° Coluna: Comprimento da pétala;
4° Coluna: Largura da pétala.

Iris Setosa
Iris Versicolour
Iris Virginica
'''
# Out:
# '\n1° Coluna: Valores do comprimento da sépalas;\n2° Coluna: Valores da largula da sépala;\n3° Coluna: Comprimento da pétala;\n4° Coluna: Largura da pétala.\n\nIris Setosa\nIris Versicolour\nIris Virginica\n'

# %%
data = np.genfromtxt('data/iris.data', delimiter=',', usecols = (0, 1, 2, 3))
process = Process(data)

# %%
process.plotSetosa()

# %%
process.plotVscolor()

# %%
process.plotCompSetVs()

# %%
'''
Com esta análise é possível concluir que o comprimento das sépalas da iris setosa são menores que as sépalas da iris versicolour
'''
